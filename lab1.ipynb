# %%
print("hello world")
# Out:
# hello world

# %%
print(54+56)
# Out:
# 110

# %%
season = "Fall"
year = "2022"

print(season)
print(year)
# Out:
# Fall
# 2022

# %%
name = input("Please Enter your name:")
print("Your name is {}".format(name))
# Out:
# Please Enter your name:john
# Your name is john

# %%
M = int(input("Please enter the M value:"))
N = int(input("Please enter the N value:"))

output = M**N
print("{}^{}:{}".format(M,N,output))
# Out:
# Please enter the M value:10
# Please enter the N value:3
# 10^3:1000

# %%
weight = int(input("please enter weight:"))

output = (weight - (weight%4))

print(output)
# Out:
# please enter weight:23
# 20

# %%
A = int(input("Enter value of A:"))
B = int(input("Enter value of B:"))
C = int(input("Enter value of C:"))

D = float(input("Enter the value of D:"))

output = ((A**C) + (B*A)-(D/3))

print(int(output))
# Out:
# Enter value of A:88
# Enter value of B:22
# Enter value of C:1
# Enter the value of D:2.3
# 2023

# %%
choco = int(input("Please enter the number:"))

each_friends_have = choco//3
remains = choco%3

print("Each friend will receive {} chocolates" 
                                        .format(each_friends_have))
print("The number of remaining chocolates is {}" 
      .format(remains))
# Out:
# Please enter the number:50
# Each friend will receive 16 chocolates
# The number of remaining chocolates is 2

# %%
M = input("Please enter value of M:")
N = input("Please enter value of N:")

print(N+M)
# Out:
# Please enter value of M:Hello
# Please enter value of N:World
# WorldHello

# %%
Text = input("Please enter your text:")

print(Text[0])

# %%
num = int(input("Please enter the Value:"))

if num%2 == 0 :
  print("True")
else :
    print("false")
# Out:
# Please enter the Value:-11
# false
