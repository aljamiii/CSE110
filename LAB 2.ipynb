# %% [markdown]
# #TASK1

# %%
num1 = int(input("First number:"))
num2 = int(input("Second number:"))

sum = num1 + num2
product = num1 * num2
difference = num1 - num2

print("Sum =",sum)
print("Product =",product)
print("Difference =",difference)
# Out:
# First number:4
# Second number:5
# Sum = 9
# Product = 20
# Difference = -1

# %% [markdown]
# #TASK2

# %%
import math

rad = float(input("Enter radius:"))

area = math.pi * math.pow(rad,2)

circum = 2*math.pi*rad

print("Area is",area)
print("Circumference is",circum)
# Out:
# Enter radius:3.5
# Area is 38.48451000647496
# Circumference is 21.991148575128552

# %% [markdown]
# #task3

# %%
x = int(input("Enter first number:"))
y = int(input("Enter second number:"))

if x>y:
  print("First is greater")
elif x<y:
  print("Second is greater")
else:
  print("The numbers are equal")
# Out:
# Enter first number:-50
# Enter second number:-4
# Second is greater

# %% [markdown]
# #task4

# %%
x = int(input("Enter first number:"))
y = int(input("Enter second number:"))

if x>y :
  print(x - y)
elif y>x:
  print(y-x)
else:
  print(0)
# Out:
# Enter first number:-40
# Enter second number:-4
# 36

# %% [markdown]
# #task5

# %%
num = int(input("Enter  number:"))

if num%2==0 :
  print("The number is even")
else:
  print("The number is odd")
# Out:
# Enter  number:-44
# The number is even

# %% [markdown]
# #task6

# %%
num = int(input("Enter your number:"))

if num%2==0 or num%5==0:
  print(num)
else:
  print("Not a multiple of 2 OR 5")
# Out:
# Enter your number:3
# Not a multiple of 2 OR 5

# %% [markdown]
# #task7

# %%
num = int(input("Enter your number:"))

if (num%2==0 and num%5!=0) or (num%2!=0 and num%5==0):
  print(num)
elif num%2==0 and num%5==0:
  print("multiple of 2 and 5 both")
else:
  print("Not a multiple we want")
# Out:
# Enter your number:17
# Not a multiple we want

# %% [markdown]
# #task8

# %%
num = int(input("Enter number:"))

if num%2==0 and num%5==0 :
  print(num)
else:
  print("Not a multiple of 2 and 5")
# Out:
# Enter number:6
# Not a multiple of 2 and 5

# %% [markdown]
# #task9

# %%
seconds = int(input("Enter second:"))

hour = seconds//3600
seconds = seconds%3600
min = seconds//60
seconds = seconds%60

print("Hours:{} Minutes:{} Seconds:{}".format(hour,min,seconds))
# Out:
# Enter second:-5000
# Hours:-2 Minutes:36 Seconds:40

# %% [markdown]
# #task10

# %%
hour = int(input("Enter value:"))

if hour<=40 and hour>=0 :
  print(hour*200)
elif hour>40 and hour<=168:
  print(8000 + (hour-40)*300)
elif hour<0:
  print("Hour cannot be negetive")
else:
  print("Impossible to work more than 168 hours weekly")
# Out:
# Enter value:169
# Impossible to work more than 168 hours weekly

# %% [markdown]
# #task11

# %%
S = int(input("Enter value:"))


if S<100:
  L = 3000-(125)*(S**2)
  print(L)
else:
  l = (12000/(4+(S**2)/14900))
  print(l)
# Out:
# Enter value:3
# 1875

# %% [markdown]
# #task12

# %%
hour = int(input("Entre time:"))

if hour>=0 and hour<24:
  if hour>=4 and hour<=6:
    print("Breakfast")
  elif hour>=12 and hour<=13:
    print("Lunch")
  elif hour>=16 and hour<=17:
    print("Snacks")
  elif hour>=19 and hour<=20:
    print("dinner")
  else:
    print("Paitence is a virtue")
else:
  print("wrong time")
# Out:
# Entre time:-55
# wrong time

# %% [markdown]
# #task13

# %%
mark = int(input("Enter mark:"))

if mark>=0 and mark<=100:

  if mark>=90 and mark<=100:
    print("A")
  elif mark>=80 and mark<=89:
    print("B")
  elif mark>=70 and mark<=79:
    print("C")
  elif mark>=60 and mark<=69:
    print("D")
  elif mark>=50 and mark<=59:
    print("E")
  else:
    print("F")
else:
  print("Not valid")
# Out:
# Enter mark:-8
# Not valid

# %% [markdown]
# #task14

# %%
distance = int(input("enter distance:"))
time = int(input("Enter time:"))

distance_km = distance/1000
time_h = time/3600

output = distance_km/time_h

if output<60 :
  print(output,"km/h")
  print("Too slow. Needs more changes.")
elif output>=60 and output<=90:
  print(output,"km/h")
  print("Velocity is okay. The car is ready!")
elif output>90:
  print("Too fast. Only a few changes should suffice.")
# Out:
# enter distance:160000
# Enter time:7200
# 80.0 km/h
# Velocity is okay. The car is ready!

# %% [markdown]
# #task15

# %%
cgpa = float(input("Enter CGPA:"))
credit = int(input("Enter Credits:"))

if credit>=30 and cgpa>=3.8:
  if cgpa>=3.80 and cgpa<=3.89:
    print("The student is eligible for a waiver of 25 percent")
  elif cgpa>=3.90 and cgpa<=3.94:
    print("The student is eligible for a waiver of 50 percent")
  elif cgpa>=3.95 and cgpa<=3.99:
    print("The student is eligible for a waiver of 75 percent")
  elif cgpa==4.00:
    print("The student is eligible for a waiver of 100 percent")
else:
  print("The student is not eligible for a waiver")
# Out:
# Enter CGPA:3.95
# Enter Credits:67
# The student is eligible for a waiver of 75 percent

# %% [markdown]
# #task16

# %%
p = 5
q = 6
r = 9
sum = 0
if (p < 12):
    print(r + 2)
else:
    print(r + p)
if (q > 20):
    print(r + 19)
elif (q <= 6):
    print(q + 3)
else:
    print(p + q + r)
if (r > 15):
    print(r)
elif (r == 0):
    print(p + q)
else:
    print(p)
if (sum != 0):
    print(3)
else:
    print(sum + 32)
if (p>0 and r<10):
    print(p+r)
else:
    print(p-r)
# Out:
# 11
# 9
# 5
# 32
# 14

# %%
var1 = False
var2 = False
var3 = False
var4 = False
var5 = False
var6 = False
result1 = False
result2 = False
result3 = False
result4 = False
result5 = False
result6 = False
result7 = False
result8 = False
result9 = False
result10 = False
var1 = ((not True) or True) and False
var2 = var1 and False
var3 = True and not False
var4 = False
var5 = True
var6 = var3 and False
result1 = (var1 and var2) and (40 % 3) > 45 or (var5 and var6)
print(result1)
result2 = (var1 or var2) or (result1 and False)
print(result2)
result3 = (var1 and result1) or result2 or var5
print(result3)
result4 = (var1 or var2) or ((var3 and var1) and False)
print(result4)
result5 = (var1 and var2) and (result3 or var1)
print(result5)
result6 = ((var3 or (not var2)) and (result5)) or True
print(result6)
result7 = (var4 and result1) and ((result1 and False) or True)
print(result7)
result8 = ((var1 and result3) and ((not var5) or var6)) and True
print(result8)
result9 = ((result2 and var2) or ((not result7) and var1)) and not False
print(result9)
result10 = not(var1 and True)
print(result10)
# Out:
# False
# False
# True
# False
# False
# True
# False
# False
# False
# True

# %%
var1 = int(input("Enter no. of canvas:"))
var2 = int(input("Enter no. of paint tube:"))

total = 120*var1 + 75*var2

if total>=0 and total<=300:
  print("previous total:",total)
  print("New total after discount:",total)
elif total>=300 and total<=499:
  print("previous total:",total)
  print("New total after discount:",(total-10))
elif total>=500 and total<=749:
  print("previous total",total)
  print("New total after discount:",total-20)
elif total>=750 and total<=999:
  print("previous total",total)
  print("New total after discount:",total-50)
elif total>=1000:
  print("Previous total:",total)
  print("New total after discount:",total-150)
# Out:
# Enter no. of canvas:0
# Enter no. of paint tube:3
# previous total: 225
# New total after discount: 225

# %%
temp = int(input("Please entere temperature"))

celsias = ((temp-32)*0.56)
celsias = round(celsias,2)
print(celsias)
if celsias<20:
  print("Winter")
elif celsias>=20 and celsias<=25:
  print("Autum")
elif celsias>25 and celsias<30:
  print("spring")
else:
  print("summer")
# Out:
# Please entere temperature77
# 25.2
# spring
