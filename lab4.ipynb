# %% [markdown]
# #task1

# %%
words=str(input("Enter word:"))
print(words[-1::-1])
# Out:
# Enter word:python
# nohtyp

# %% [markdown]
# #task2

# %%
word= str(input("Enter string:"))
index=int(input("Enter iondex no:"))
first=word[index::-1]
second=word[index+1:]

print(first+second)
# Out:
# Enter string:123456
# Enter iondex no:2
# 321456

# %% [markdown]
# #task3

# %%
word=input("Enter string:")

for i in word:
  if i=="0" or i=="1":
    output="binary number"
  else:
    output="not a binary number"
    break
print(output)
# Out:
# Enter string:0010111412
# not a binary number

# %% [markdown]
# #task4

# %%
word=str(input("please, Enter string:"))
length=len(word)

if word[length-2]=="e" and word[length-1]=="r":
  print(word[0:length-2]+"est")
elif word[length-3]=="e" and word[length-2]=="s" and word[length-1]=="t":
  print(word)
elif length>3:
  print(word+"er") 
elif length<4:
  print(word)
# Out:
# please, Enter string:ber
# best

# %% [markdown]
# #task5

# %%
word=str(input("Enter string:"))
length=len(word)
for x in range(0,length+1):
  a=word[:x]
  print(a)
# Out:
# Enter string:DREAM
#
# D
# DR
# DRE
# DREA
# DREAM

# %%
word= str(input("enter:"))
length=len(word)
row=1
x=0

while row<=length:
  coloum=1
  while coloum<=row:
    while x<=length:
      num=word[:x]
      print(num)
      x+=1
    coloum+=1
  row+=1
# Out:
# enter:BANGLA
#
# B
# BA
# BAN
# BANG
# BANGL
# BANGLA

# %% [markdown]
# #task6

# %%
word=input("enter:")

for chr in word:
  ascii=ord(chr)
  print("{}:{}".format(chr,ascii))
# Out:
# enter:hunger
# h:104
# u:117
# n:110
# g:103
# e:101
# r:114

# %% [markdown]
# #task7

# %%
word=input("enter:")

for char in word:
  if ord(char)==122:
    print(chr(97),end="")
  else:
    y=chr(ord(char)+1)
    print(y,end="")
# Out:
# enter:afbeu
# bgcfv

# %% [markdown]
# #task8

# %%
word=input("enter:")
length=len(word)
store=""
for i in range(1,length+1,2):
  a=word[i]
  b=ord(a)
  c=chr(b-32)
  print(c,end="")
# Out:
# enter:abcd
# BD

# %% [markdown]
# #task9

# %%
word=(input("Enter string:"))
new=""
for i in word:
  if new=="":
    print(i,end="")
    new=i
  elif i==new:
    continue
  else:
    print(i,end="")
    new=i
# Out:
# Enter string:jupyter notebok is better. Case sesi AAaaaAaaAAAa
# jupyter notebok is beter. Case sesi AaAaAa

# %% [markdown]
# #task10

# %%
word=input("enter:")
length=len(word)
for i in range(0,length+1):
  
  if word[i]==",":
    break

first=word[:i]
second=word[i+2:]

if len(first)<len(second):
  small=first
  lonnger=second
elif len(second)<len(first):
  small=second
  longer=first
else:
  small=second
  longer=first
new_word=""
for j in range(len(small)):
  new_word=new_word+first[j]+second[j]
print(new_word+longer[len(small):])
# Out:
# enter:ABCDENDFGH, ijkl
# AiBjCkDlENDFGH

# %%
#task11

i = 10
while(i >= -20):
    if(i < 0):
        test = " != "
        test = str(i//2) + test + str(int(i/2))
    else:
        test = " == "
        test = str(i//2) + test + str(int(i/2))
    print(test)
    i -= 5
# Out:
# 5 == 5
# 2 == 2
# 0 == 0
# -3 != -2
# -5 != -5
# -8 != -7
# -10 != -10

# %%
#task12

test = ""
i = 0
j = 0
k = 15
test = "-->"
while i < 5:
    j = k - 1
    k -= 1
    while j > 10:
        test = str(i + j) + "-->" + test
        print(test)
        j -= 1
    i += 1
# Out:
# 14-->-->
# 13-->14-->-->
# 12-->13-->14-->-->
# 11-->12-->13-->14-->-->
# 14-->11-->12-->13-->14-->-->
# 13-->14-->11-->12-->13-->14-->-->
# 12-->13-->14-->11-->12-->13-->14-->-->
# 14-->12-->13-->14-->11-->12-->13-->14-->-->
# 13-->14-->12-->13-->14-->11-->12-->13-->14-->-->
# 14-->13-->14-->12-->13-->14-->11-->12-->13-->14-->-->

# %%
#task13

test = ""
i = 5
j = 0
k = 15
while i< 10:
    k-=1
    j = k
    while j > 10:
        if (j % 2) == 0:
            test = "<--"
            test = str(test) + str(i) + str(2) + "-->" + str(int(j / 2))  
        else:
            test = "-->"
            test = "-->" + str(int(i / 2)) + str(test) + str(j)
        print(test)
        j = j-1
    i+=1
# Out:
# <--52-->7
# -->2-->13
# <--52-->6
# -->2-->11
# -->3-->13
# <--62-->6
# -->3-->11
# <--72-->6
# -->3-->11
# -->4-->11

# %%
#14
test = ""
i = 5
j = 0
k = 15
while (i< 10): 
    k-=1
    j = k
    while (j > 10 ):
        if j % 2 == 0:
            test = "<--"
            test = test + str(i) + '3' + "-->" + str(j // 3)
        else:
            test = "-->"
            test = "-->" + str((i // 3)) + test + str(j)
        print(test)
        j -=1
    i+=1
# Out:
# <--53-->4
# -->1-->13
# <--53-->4
# -->1-->11
# -->2-->13
# <--63-->4
# -->2-->11
# <--73-->4
# -->2-->11
# -->2-->11

# %%
#task13
test = ""
i = 5
j = 0
k = 15
while i< 10:
    k-=1
    j = k
    while j > 10:
        if (j % 2) == 0:
            test = "<--"
            test = str(test) + str(i) + str(2) + "-->" + str(int(j / 2))  
        else:
            test = "-->"
            test = "-->" + str(int(i / 2)) + str(test) + str(j)
        print(test)
        j = j-1
    i+=1
# Out:
# <--52-->7
# -->2-->13
# <--52-->6
# -->2-->11
# -->3-->13
# <--62-->6
# -->3-->11
# <--72-->6
# -->3-->11
# -->4-->11

# %%
#task15
i=0
j=0
k=15
test = '<--cat'
while i < 5:
    k -= 1
    j = k
    while j > 10:
        if j % 2 == 0:
            test += '-->'
            test = test + str(i) + str(j // 2)
        else:
            test += '<--'
            test = test + str(i // 2) + str(j)
        print(test)
        j-=1
    i+=1
# Out:
# <--cat-->07
# <--cat-->07<--013
# <--cat-->07<--013-->06
# <--cat-->07<--013-->06<--011
# <--cat-->07<--013-->06<--011<--013
# <--cat-->07<--013-->06<--011<--013-->16
# <--cat-->07<--013-->06<--011<--013-->16<--011
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26<--111
# <--cat-->07<--013-->06<--011<--013-->16<--011-->26<--111<--111
